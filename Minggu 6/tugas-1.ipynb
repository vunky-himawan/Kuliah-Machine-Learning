# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
df = pd.read_csv('Minggu 6/data/mushrooms.csv')

df.head(-1)
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8118     p         k           y         n       f    f               f
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %%
df.columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %%
feature_columns = ['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
       'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
       'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
       'stalk-surface-below-ring', 'stalk-color-above-ring',
       'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
       'ring-type', 'spore-print-color', 'population', 'habitat']

for column in feature_columns:
    print("===========================================")
    print(f"{column} ==> Missing zeros : {len(df.loc[df[column] == '?'])}")
# Out:
# ...
# class ==> Missing zeros : 0
# ...
# cap-shape ==> Missing zeros : 0
# ...
# cap-surface ==> Missing zeros : 0
# ...
# cap-color ==> Missing zeros : 0
# ...
# bruises ==> Missing zeros : 0
# ...
# odor ==> Missing zeros : 0
# ...
# gill-attachment ==> Missing zeros : 0
# ...
# gill-spacing ==> Missing zeros : 0
# ...
# gill-size ==> Missing zeros : 0
# ...
# gill-color ==> Missing zeros : 0
# ...
# stalk-shape ==> Missing zeros : 0
# ...
# stalk-root ==> Missing zeros : 2480
# ...
# stalk-surface-above-ring ==> Missing zeros : 0
# ...
# stalk-surface-below-ring ==> Missing zeros : 0
# ...
# stalk-color-above-ring ==> Missing zeros : 0
# ...
# stalk-color-below-ring ==> Missing zeros : 0
# ...
# veil-type ==> Missing zeros : 0
# ...
# veil-color ==> Missing zeros : 0
# ...
# ring-number ==> Missing zeros : 0
# ...
# ring-type ==> Missing zeros : 0
# ...
# spore-print-color ==> Missing zeros : 0
# ...
# population ==> Missing zeros : 0
# ...
# habitat ==> Missing zeros : 0

# %%
from sklearn.impute import SimpleImputer

fill_values = SimpleImputer(missing_values='?', strategy='most_frequent', copy=False)

df[feature_columns] = fill_values.fit_transform(df[feature_columns])

# %%
feature_columns = ['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
       'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
       'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
       'stalk-surface-below-ring', 'stalk-color-above-ring',
       'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
       'ring-type', 'spore-print-color', 'population', 'habitat']

for column in feature_columns:
    print("===========================================")
    print(f"{column} ==> Missing zeros : {len(df.loc[df[column] == '?'])}")
# Out:
# ...
# class ==> Missing zeros : 0
# ...
# cap-shape ==> Missing zeros : 0
# ...
# cap-surface ==> Missing zeros : 0
# ...
# cap-color ==> Missing zeros : 0
# ...
# bruises ==> Missing zeros : 0
# ...
# odor ==> Missing zeros : 0
# ...
# gill-attachment ==> Missing zeros : 0
# ...
# gill-spacing ==> Missing zeros : 0
# ...
# gill-size ==> Missing zeros : 0
# ...
# gill-color ==> Missing zeros : 0
# ...
# stalk-shape ==> Missing zeros : 0
# ...
# stalk-root ==> Missing zeros : 0
# ...
# stalk-surface-above-ring ==> Missing zeros : 0
# ...
# stalk-surface-below-ring ==> Missing zeros : 0
# ...
# stalk-color-above-ring ==> Missing zeros : 0
# ...
# stalk-color-below-ring ==> Missing zeros : 0
# ...
# veil-type ==> Missing zeros : 0
# ...
# veil-color ==> Missing zeros : 0
# ...
# ring-number ==> Missing zeros : 0
# ...
# ring-type ==> Missing zeros : 0
# ...
# spore-print-color ==> Missing zeros : 0
# ...
# population ==> Missing zeros : 0
# ...
# habitat ==> Missing zeros : 0

# %%
X = df.drop('class', axis=1)
y = df['class']

# %%
X_encoded = pd.get_dummies(X, drop_first=True)

X_encoded.head()
# Out:
#    cap-shape_c  cap-shape_f  cap-shape_k  cap-shape_s  cap-shape_x  \
# 0        False        False        False        False         True
# 1        False        False        False        False         True
# 2        False        False        False        False        False
# 3        False        False        False        False         True
# 4        False        False        False        False         True
#
#    cap-surface_g  cap-surface_s  cap-surface_y  cap-color_c  cap-color_e  ...  \
# 0          False           True          False        False        False  ...
# 1          False           True          False        False        False  ...
# 2          False           True          False        False        False  ...
# 3          False          False           True        False        False  ...
# 4          False           True          False        False        False  ...
#
#    population_n  population_s  population_v  population_y  habitat_g  \
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# %%
dt = DecisionTreeClassifier(random_state=42)
rf = RandomForestClassifier(random_state=42)

# %%
dt.fit(X_train, y_train)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred_dt = dt.predict(X_test)
y_pred_rf = rf.predict(X_test)

# %%
accuracy_dt = accuracy_score(y_test, y_pred_dt)
accuracy_rf = accuracy_score(y_test, y_pred_rf)

print(f'Accuracy Decision Tree: {accuracy_dt}')
print(f'Accuracy Random Forest: {accuracy_rf}')
# Out:
# Accuracy Decision Tree: 1.0
# Accuracy Random Forest: 1.0

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid_dt = {
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 10, 20],
    'min_samples_leaf': [1, 5, 10]
}

grid_search_dt = GridSearchCV(DecisionTreeClassifier(random_state=42), param_grid_dt, cv=5, scoring='accuracy')
grid_search_dt.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=42),
#              param_grid={'max_depth': [None, 10, 20, 30],
#                          'min_samples_leaf': [1, 5, 10],
#                          'min_samples_split': [2, 10, 20]},
#              scoring='accuracy')

# %%
param_grid_rf = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 10, 20],
    'min_samples_leaf': [1, 5, 10]
}

# %%
grid_search_rf = GridSearchCV(RandomForestClassifier(random_state=42), param_grid_rf, cv=5, scoring='accuracy')
grid_search_rf.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42),
#              param_grid={'max_depth': [None, 10, 20, 30],
#                          'min_samples_leaf': [1, 5, 10],
#                          'min_samples_split': [2, 10, 20],
#                          'n_estimators': [100, 200, 300]},
#              scoring='accuracy')

# %%
best_dt = grid_search_dt.best_estimator_
best_rf = grid_search_rf.best_estimator_
best_accuracy_dt = grid_search_dt.best_score_
best_accuracy_rf = grid_search_rf.best_score_

print(f'Best Accuracy Decision Tree: {best_accuracy_dt}')
print(f'Best Parameters Decision Tree: {grid_search_dt.best_params_}')
print(f'Best Accuracy Random Forest: {best_accuracy_rf}')
print(f'Best Parameters Random Forest: {grid_search_rf.best_params_}')
# Out:
# Best Accuracy Decision Tree: 1.0
# Best Parameters Decision Tree: {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Best Accuracy Random Forest: 1.0
# Best Parameters Random Forest: {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}

# %%
y_pred_best_dt = best_dt.predict(X_test)
y_pred_best_rf = best_rf.predict(X_test)

best_accuracy_dt_test = accuracy_score(y_test, y_pred_best_dt)
best_accuracy_rf_test = accuracy_score(y_test, y_pred_best_rf)

print(f'Best Accuracy Decision Tree on Test Set: {best_accuracy_dt_test}')
print(f'Best Accuracy Random Forest on Test Set: {best_accuracy_rf_test}')
# Out:
# Best Accuracy Decision Tree on Test Set: 1.0
# Best Accuracy Random Forest on Test Set: 1.0
